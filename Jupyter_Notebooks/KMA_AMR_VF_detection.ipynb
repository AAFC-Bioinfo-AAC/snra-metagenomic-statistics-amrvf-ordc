# %%
# Filtering readbased KMA detection of AMR gene and VF
# Author: Dr. Haley Sanderson haley.sanderson@agr.gc.ca
# Copyright: Government of Canada
# License: MIT
# Version 0.1
import os
import pandas as pd

# Set the directory path
directory_path = './'

# Get a list of all files ending with "AMR.res"
amr_files = [f for f in os.listdir(directory_path) if f.endswith('AMR.res')]

# Initialize an empty DataFrame to store the concatenated data
combined_data = pd.DataFrame()

# Loop through each file and concatenate the data
for amr_file in amr_files:
    file_path = os.path.join(directory_path, amr_file)

    # Specify column names while reading the file
    gene_data = pd.read_csv(file_path, sep='\t', names=["#Template", "Score", "Expected", "Template_length", "Template_Identity", "Template_Coverage", "Query_Identity", "Query_Coverage", "Depth", "q_value", "p_value"])

    # Add a new column with the file name
    gene_data['FileName'] = amr_file

    # Filter out rows where '#Template' column contains 'RequiresSNPConfirmation'
    gene_data_noSNP = gene_data[~gene_data['#Template'].str.contains('RequiresSNPConfirmation', case=False)]
    
    # Concatenate the data to the combined DataFrame
    combined_data = pd.concat([combined_data, gene_data_noSNP], ignore_index=True)
    combined_data = combined_data[~combined_data['#Template'].str.contains('#template', case=False)]
# Display the combined DataFrame
print(combined_data)
# Out:
#                                             #Template     Score  Expected  \
# 0   MEG_997|Drugs|Aminoglycosides|Aminoglycoside_O...      5296       648
# 1   MEG_6997|Drugs|Tetracyclines|Tetracycline_resi...     11826      1452
# 2   MEG_7112|Drugs|Tetracyclines|Tetracycline_resi...      8327      1450
# 3   MEG_3641|Drugs|MLS|MLS_resistance_ABC_efflux_p...      6424      1344
# 4   MEG_3648|Drugs|Multi-drug_resistance|Multi-dru...      4183       728
# 5   MEG_7112|Drugs|Tetracyclines|Tetracycline_resi...      7660      1738
# 6   MEG_3896|Metals|Mercury_resistance|Mercury_res...      1349       297
# 7   MEG_2566|Drugs|Trimethoprim|Dihydrofolate_redu...       736       332
# 8   MEG_988|Drugs|Aminoglycosides|Aminoglycoside_O...      3691       609
# 9   MEG_997|Drugs|Aminoglycosides|Aminoglycoside_O...     10080       602
# 10  MEG_1000|Drugs|Aminoglycosides|Aminoglycoside_...      6402       607
# 11  MEG_1004|Drugs|Aminoglycosides|Aminoglycoside_...      4091       569
# 12  MEG_1554|Drugs|Phenicol|Chloramphenicol_acetyl...      3176       464
# 13  MEG_3610|Drugs|MLS|Lincosamide_nucleotidyltran...      2631       348
# 14  MEG_3641|Drugs|MLS|MLS_resistance_ABC_efflux_p...     29362      1040
# 15  MEG_3648|Drugs|Multi-drug_resistance|Multi-dru...     16526       564
# 16  MEG_3826|Drugs|MLS|MLS_resistance_MFS_efflux_p...      5461       856
# 17  MEG_3827|Drugs|MLS|MLS_resistance_MFS_efflux_p...      7203       864
# 18  MEG_6997|Drugs|Tetracyclines|Tetracycline_resi...     15635      1350
# 19  MEG_6998|Drugs|Tetracyclines|Tetracycline_resi...     21061      1348
# 20  MEG_7112|Drugs|Tetracyclines|Tetracycline_resi...     41796      1342
# 21  MEG_7129|Drugs|Tetracyclines|Tetracycline_resi...      9406      1349
# 22  MEG_7183|Drugs|Tetracyclines|Tetracycline_resi...     15770      1352
# 23  MEG_7202|Drugs|Tetracyclines|Tetracycline_resi...     13695      1373
# 24  MEG_7229|Drugs|Tetracyclines|Tetracycline_resi...     15957      1359
# 25  MEG_2833|Drugs|MLS|23S_rRNA_methyltransferases...      3663       544
# 26  MEG_3828|Drugs|MLS|MLS_resistance_MFS_efflux_p...      4488       832
# 27  MEG_4045|Drugs|MLS|Macrolide_phosphotransferas...      3777       601
# 28  MEG_6153|Multi-compound|Biocide_and_metal_resi...     10651      1865
# 29  MEG_6543|Biocides|Peroxide_resistance|peroxide...       841       252
# 30  MEG_6546|Biocides|Peroxide_resistance|peroxide...      7172       978
# 31  MEG_3641|Drugs|MLS|MLS_resistance_ABC_efflux_p...     10644      1714
# 32  MEG_3648|Drugs|Multi-drug_resistance|Multi-dru...      8814       928
# 33  MEG_6546|Biocides|Peroxide_resistance|peroxide...      5840       633
# 34  MEG_3610|Drugs|MLS|Lincosamide_nucleotidyltran...      1571       618
# 35  MEG_2723|Multi-compound|Drug_and_biocide_resis...     10253      1356
# 36  MEG_2726|Multi-compound|Drug_and_biocide_resis...     10151      1822
# 37  MEG_6522|Multi-compound|Drug_and_biocide_resis...     22574      3581
# 38  MEG_3870|Metals|Mercury_resistance|Mercury_res...       798       303
# 39  MEG_948|Drugs|Aminoglycosides|Aminoglycoside_O...      8527      1284
# 40  MEG_1045|Drugs|Aminoglycosides|Aminoglycoside_...      2810      1309
# 41  MEG_1086|Drugs|Aminoglycosides|Aminoglycoside_...      2162      1362
# 42  MEG_3911|Multi-compound|Drug_and_biocide_resis...     20799      5172
# 43  MEG_5044|Drugs|betalactams|Class_D_betalactama...      3785      1343
# 44  MEG_6153|Multi-compound|Biocide_and_metal_resi...     11818      1941
# 45  MEG_6546|Biocides|Peroxide_resistance|peroxide...     10677       947
# 46  MEG_6987|Drugs|Tetracyclines|Tetracycline_resi...     18786      1932
# 47  MEG_3828|Drugs|MLS|MLS_resistance_MFS_efflux_p...      5841       892
# 48  MEG_3391|Drugs|betalactams|Class_B_betalactama...     22820      1253
# 49  MEG_2566|Drugs|Trimethoprim|Dihydrofolate_redu...       597       213
# 50  MEG_6546|Biocides|Peroxide_resistance|peroxide...      8506      1266
# 51  MEG_3857|Metals|Mercury_resistance|Mercury_res...       992       345
# 52  MEG_3874|Metals|Mercury_resistance|Mercury_res...       344       225
#
#    Template_length Template_Identity Template_Coverage Query_Identity  \
# 0              858             85.20             85.20         100.00
# 1             1923             81.59             82.32          99.12
# 2             1920             86.20             86.30          99.88
# 3             1485             92.93             95.42          97.39
# 4              804             92.29             94.15          98.02
# 5             1920             84.43             84.48          99.94
# 6              351             87.75             99.15          88.51
# 7              237             86.50             90.30          95.79
# 8              867             81.55             81.55         100.00
# 9              858            100.00            100.00         100.00
# 10             864             98.84            100.00          98.84
# 11             810             98.02            100.00          98.02
# 12             660             99.70            100.00          99.70
# 13             495             90.91             93.13          97.61
# 14            1485             99.87            100.00          99.87
# 15             804            100.00            100.00         100.00
# 16            1218             80.30             84.24          95.32
# 17            1230             96.91            100.00          96.91
# 18            1923             97.19             97.71          99.47
# 19            1923             98.34             98.60          99.74
# 20            1920             99.95            100.00          99.95
# 21            1920             80.00             80.00         100.00
# 22            1926             98.34             98.65          99.68
# 23            1956             94.94             97.90          96.97
# 24            1937             97.73             97.73         100.00
# 25             801             80.15             80.15         100.00
# 26            1224             94.36             94.44          99.91
# 27             885             98.98             99.21          99.77
# 28            1193             81.48             87.43          93.19
# 29             288             84.72             84.72         100.00
# 30             582             82.47             91.58          90.06
# 31            1485             93.13             95.42          97.60
# 32             804             98.26            100.00          98.26
# 33             582             89.00             97.42          91.36
# 34             495             87.88             89.09          98.64
# 35            1182             89.17             94.25          94.61
# 36            1587             85.44             93.26          91.62
# 37            3123             82.20             88.41          92.97
# 38             246             80.49             87.40          92.09
# 39             789            100.00            100.00         100.00
# 40             804             90.55             90.55         100.00
# 41             837             94.27             94.38          99.87
# 42            3180             88.52             97.42          90.87
# 43             825             85.09             85.58          99.43
# 44            1193             85.33             92.88          91.88
# 45             582             88.66            100.00          88.66
# 46            1188            100.00            100.00         100.00
# 47            1224             96.73             98.94          97.77
# 48             876             87.79             88.81          98.84
# 49             237             87.76             97.47          90.04
# 50             582             85.22             93.64          91.01
# 51             423             85.82             96.69          88.75
# 52             276             84.78             93.12          91.05
#
#    Query_Coverage     Depth   q_value  p_value                FileName
# 0          117.37      1.97   3633.67  1.0e-26  SN005-20171106_AMR.res
# 1          121.48      2.01   8105.02  1.0e-26  SN005-20171106_AMR.res
# 2          115.87      2.20   4836.18  1.0e-26  SN005-20171106_AMR.res
# 3          104.80      2.53   3320.97  1.0e-26  SN005-20191104_AMR.res
# 4          106.21      1.98   2430.35  1.0e-26  SN005-20191104_AMR.res
# 5          118.37      1.82   3731.01  1.0e-26  SN005-20191104_AMR.res
# 6          100.86      6.51    672.10  1.0e-26  SN018-20210712_AMR.res
# 7          110.75      1.89    152.18  1.0e-26  SN021-20211018_AMR.res
# 8          122.63      1.56   2207.57  1.0e-26  SN005-20180430_AMR.res
# 9          100.00      6.36   8407.66  1.0e-26  SN005-20180430_AMR.res
# 10         100.00      5.41   4790.42  1.0e-26  SN005-20180430_AMR.res
# 11         100.00      4.09   2660.64  1.0e-26  SN005-20180430_AMR.res
# 12         100.00      3.28   2020.21  1.0e-26  SN005-20180430_AMR.res
# 13         107.38      4.05   1749.26  1.0e-26  SN005-20180430_AMR.res
# 14         100.00     18.59  26383.76  1.0e-26  SN005-20180430_AMR.res
# 15         100.00     18.01  14907.68  1.0e-26  SN005-20180430_AMR.res
# 16         118.71      2.64   3356.22  1.0e-26  SN005-20180430_AMR.res
# 17         100.00      5.29   4979.88  1.0e-26  SN005-20180430_AMR.res
# 18         102.34      4.51  12014.20  1.0e-26  SN005-20180430_AMR.res
# 19         101.42      6.94  17339.22  1.0e-26  SN005-20180430_AMR.res
# 20         100.00     19.08  37936.11  1.0e-26  SN005-20180430_AMR.res
# 21         125.00      4.66   6035.36  1.0e-26  SN005-20180430_AMR.res
# 22         101.37      6.08  12140.84  1.0e-26  SN005-20180430_AMR.res
# 23         102.14      5.58  10075.06  1.0e-26  SN005-20180430_AMR.res
# 24         102.32      7.23  12304.80  1.0e-26  SN005-20180430_AMR.res
# 25         124.77      2.13   2311.27  1.0e-26  SN010-20170704_AMR.res
# 26         105.88      2.32   2512.39  1.0e-26  SN010-20170704_AMR.res
# 27         100.80      2.62   2302.74  1.0e-26  SN010-20170704_AMR.res
# 28         114.38      1.99   6167.11  1.0e-26  SN020-20201019_AMR.res
# 29         118.03      0.85    317.00  1.0e-26  SN005-20160718_AMR.res
# 30         109.19      2.30   4707.26  1.0e-26  SN019-20201102_AMR.res
# 31         104.80      4.78   6451.85  1.0e-26  SN020-20191021_AMR.res
# 32         100.00      7.32   6382.77  1.0e-26  SN020-20191021_AMR.res
# 33         102.65      4.79   4187.94  1.0e-26  SN019-20181113_AMR.res
# 34         112.24      1.14    414.31  1.0e-26  SN019-20190429_AMR.res
# 35         106.10      2.51   6816.50  1.0e-26  SN019-20170704_AMR.res
# 36         107.23      3.01   5794.02  1.0e-26  SN019-20170704_AMR.res
# 37         113.11      2.71  13790.60  1.0e-26  SN019-20170704_AMR.res
# 38         114.42      1.69    222.37  1.0e-26  SN024-20181113_AMR.res
# 39         100.00      8.75   5347.00  1.0e-26  SN005-20191021_AMR.res
# 40         110.44      1.72    546.97  1.0e-26  SN005-20191021_AMR.res
# 41         105.95      1.17    181.21  1.0e-26  SN005-20191021_AMR.res
# 42         102.65      5.16   9402.24  1.0e-26  SN005-20191021_AMR.res
# 43         116.86      1.89   1162.77  1.0e-26  SN005-20191021_AMR.res
# 44         107.67      6.79   7089.82  1.0e-26  SN005-20191021_AMR.res
# 45         100.00      7.45   8144.53  1.0e-26  SN005-20191021_AMR.res
# 46         100.00     12.83  13710.24  1.0e-26  SN005-20191021_AMR.res
# 47         101.07      3.93   3636.04  1.0e-26  SN021-20180807_AMR.res
# 48         112.60     28.44  19321.80  1.0e-26  SN006-20201102_AMR.res
# 49         102.60      1.95    182.00  1.0e-26  SN006-20211004_AMR.res
# 50         106.79      2.32   5362.82  1.0e-26  SN005-20201102_AMR.res
# 51         103.42      1.34    312.84  1.0e-26  SN005-20181015_AMR.res
# 52         107.39      1.50     24.77  6.5e-07  SN005-20181015_AMR.res

# %%
combined_data.to_csv("MG_AMR_read_mapping_80%_cutoff_nosnp.csv")

# %%
unique_file_names = combined_data['FileName'].unique()
unique_file_names
# Out:
# array(['SN005-20171106_AMR.res', 'SN005-20191104_AMR.res',
#        'SN018-20210712_AMR.res', 'SN021-20211018_AMR.res',
#        'SN005-20180430_AMR.res', 'SN010-20170704_AMR.res',
#        'SN020-20201019_AMR.res', 'SN005-20160718_AMR.res',
#        'SN019-20201102_AMR.res', 'SN020-20191021_AMR.res',
#        'SN019-20181113_AMR.res', 'SN019-20190429_AMR.res',
#        'SN019-20170704_AMR.res', 'SN024-20181113_AMR.res',
#        'SN005-20191021_AMR.res', 'SN021-20180807_AMR.res',
#        'SN006-20201102_AMR.res', 'SN006-20211004_AMR.res',
#        'SN005-20201102_AMR.res', 'SN005-20181015_AMR.res'], dtype=object)

# %%
import os
import pandas as pd

# Set the directory path
directory_path = './'

# Get a list of all files ending with "AMR.res"
amr_files = [f for f in os.listdir(directory_path) if f.endswith('VFDB.res')]

# Initialize an empty DataFrame to store the concatenated data
combined_data = pd.DataFrame()

# Loop through each file and concatenate the data
for amr_file in amr_files:
    file_path = os.path.join(directory_path, amr_file)

    # Specify column names while reading the file
    gene_data = pd.read_csv(file_path, sep='\t', names=["#Template", "Score", "Expected", "Template_length", "Template_Identity", "Template_Coverage", "Query_Identity", "Query_Coverage", "Depth", "q_value", "p_value"])

    # Add a new column with the file name
    gene_data['FileName'] = amr_file

    # Filter out rows where '#Template' column contains 'RequiresSNPConfirmation'
    gene_data_noSNP = gene_data[~gene_data['#Template'].str.contains('RequiresSNPConfirmation', case=False)]
    
    # Concatenate the data to the combined DataFrame
    combined_data = pd.concat([combined_data, gene_data_noSNP], ignore_index=True)
    combined_data = combined_data[~combined_data['#Template'].str.contains('#template', case=False)]
# Display the combined DataFrame
print(combined_data)
# Out:
#                                             #Template     Score  Expected  \
# 0   VFG038340(gb|WP_005320774) (acrG) Type III sec...       844       955
# 1   VFG010906(gb|WP_011213314) (csrA) carbon stora...       856       492
# 2   VFG010906(gb|WP_011213314) (csrA) carbon stora...       489       381
# 3   VFG038663(gb|WP_005298795) (fliO) flagellar bi...      1108       862
# 4   VFG000863(gb|BAA94855) (east1) heat-stable ent...       187       430
# 5   VFG001855(gb|WP_197535493) (htpB) Hsp60, 60K h...      8829      6075
# 6   VFG010906(gb|WP_011213314) (csrA) carbon stora...       539       718
# 7   VFG010906(gb|WP_011213314) (csrA) carbon stora...       732       348
# 8   VFG038659(gb|WP_011705280) (fliN) flagellar mo...      2756      1364
# 9   VFG001225(gb|NP_249099) (pilG) twitching motil...      3256      1416
# 10  VFG038346(gb|WP_005320760) (acr1) Type III sec...      1241       751
# 11  VFG010906(gb|WP_011213314) (csrA) carbon stora...      1117       661
# 12  VFG010906(gb|WP_011213314) (csrA) carbon stora...      1095       415
# 13  VFG038176(gb|WP_000777882) (ompA) outer membra...     34279      3039
# 14  VFG001256(gb|NP_250134) (fliM) flagellar motor...      7201      2762
# 15  VFG002070(gb|NP_248774) (hsiC1/vipB/tssC) type...     10310      4254
# 16  VFG043016(gb|NP_250155) (PA1464) purine-bindin...      4310      1364
# 17  VFG038876(gb|WP_005314259) (lfgG) lateral flag...      1770      1522
# 18  VFG010906(gb|WP_011213314) (csrA) carbon stora...       858       613
# 19  VFG013948(gb|NP_251650) (pilZ) type 4 fimbrial...       872       556
# 20  VFG010906(gb|WP_011213314) (csrA) carbon stora...      1004       408
#
#    Template_length Template_Identity Template_Coverage Query_Identity  \
# 0              285             84.56             88.77          95.26
# 1              195             88.21             97.44          90.53
# 2              195             81.54             94.36          86.41
# 3              384             88.80             97.66          90.93
# 4              117             83.76             93.16          89.91
# 5             1650             80.97             90.48          89.48
# 6              195             83.59             92.82          90.06
# 7              195             82.56             94.87          87.03
# 8              393             83.97             90.84          92.44
# 9              408             85.78             93.38          91.86
# 10             282             88.30             97.16          90.88
# 11             195             89.74             97.44          92.11
# 12             195             83.59             93.85          89.07
# 13            1071             87.11             97.48          89.37
# 14             972             86.73             97.33          89.11
# 15            1497             82.63             92.12          89.70
# 16             480             83.12             94.79          87.69
# 17             786             87.28             89.19          97.86
# 18             195             87.18             97.44          89.47
# 19             357             87.39             96.08          90.96
# 20             195             83.08             91.79          90.50
#
#    Query_Coverage     Depth   q_value  p_value                 FileName
# 0          112.65      1.78      6.93  8.5e-03  SN021-20210628_VFDB.res
# 1          102.63      4.26     97.99  1.0e-22  SN018-20181113_VFDB.res
# 2          105.98      1.29     13.39  2.5e-04  SN024-20161107_VFDB.res
# 3          102.40      1.30     30.61  3.2e-08  SN018-20190624_VFDB.res
# 4          107.34      0.93     96.25  1.0e-21  SN019-20201102_VFDB.res
# 5          110.52      2.71    508.71  1.0e-26  SN019-20201102_VFDB.res
# 6          107.73      1.23     25.52  4.4e-07  SN019-20201102_VFDB.res
# 7          105.41      2.32    136.51  1.0e-26  SN018-20210712_VFDB.res
# 8          110.08      1.47    469.85  1.0e-26  SN020-20201019_VFDB.res
# 9          107.09      2.72    724.06  1.0e-26  SN020-20201019_VFDB.res
# 10         102.92      2.01    120.15  1.0e-26  SN019-20210531_VFDB.res
# 11         102.63      1.10    116.90  1.0e-26  SN010-20190513_VFDB.res
# 12         106.56      1.11    305.17  1.0e-26  SN024-20210517_VFDB.res
# 13         102.59     43.14  26151.70  1.0e-26  SN005-20191021_VFDB.res
# 14         102.75      4.45   1976.73  1.0e-26  SN005-20191021_VFDB.res
# 15         108.56      4.27   2517.33  1.0e-26  SN005-20191021_VFDB.res
# 16         105.49      5.90   1528.86  1.0e-26  SN005-20191021_VFDB.res
# 17         112.13      1.62     18.57  1.6e-05  SN020-20180528_VFDB.res
# 18         102.63      1.78     40.51  7.1e-10  SN018-20191021_VFDB.res
# 19         104.08      1.37     69.46  1.0e-16  SN018-20180807_VFDB.res
# 20         108.94      2.75    251.27  1.0e-26  SN021-20170704_VFDB.res

# %%
combined_data.to_csv("MG_VFDB_read_mapping_80%_cutoff_nosnp.csv")

# %%
unique_file_names = combined_data['FileName'].unique()

# %%
unique_file_names
# Out:
# array(['SN021-20210628_VFDB.res', 'SN018-20181113_VFDB.res',
#        'SN024-20161107_VFDB.res', 'SN018-20190624_VFDB.res',
#        'SN019-20201102_VFDB.res', 'SN018-20210712_VFDB.res',
#        'SN020-20201019_VFDB.res', 'SN019-20210531_VFDB.res',
#        'SN010-20190513_VFDB.res', 'SN024-20210517_VFDB.res',
#        'SN005-20191021_VFDB.res', 'SN020-20180528_VFDB.res',
#        'SN018-20191021_VFDB.res', 'SN018-20180807_VFDB.res',
#        'SN021-20170704_VFDB.res'], dtype=object)
